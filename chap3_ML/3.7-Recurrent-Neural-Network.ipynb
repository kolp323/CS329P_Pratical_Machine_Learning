# %% [markdown]
# # 3.7 循环神经网络 RNN

# %% [markdown]
# 将最终输出的激活值 H 和输入做一个 concat，从而每次输入都携带了历史信息+新词
#
# <img src="paste_image/2026-01-28-18-08-02.png" width="68%">

# %% [markdown]
# ### Simple RNN
# <img src="paste_image/2026-01-28-18-09-52.png" width="68%">

# %% [markdown]
# ### Gated RNN (如LSTM, GRU)
# 更好的控制消息流
#
# - Forget input: suppress $\mathbf{x}_t$ when computing $\mathbf{h}_t$
# - Forget past: suppress $\mathbf{h}_{t-1}$ when computing $\mathbf{h}_t$

# %% [markdown]
# ### Bi-RNN and Deep RNN
#
# <img src="paste_image/2026-01-28-18-14-56.png" width="68%">
